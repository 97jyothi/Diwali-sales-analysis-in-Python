# %%
# import python libraries

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# %%
# import csv file
df = pd.read_csv('Diwali Sales Data.csv', encoding= 'unicode_escape')

# %%
#Checking no. of rows and columns
df.shape
# Out:
# (11251, 15)

# %%
#First five rows
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
#Dropping the complete bank columns
df.drop(['Status','unnamed1'],axis=1,inplace=True)

# %%
#Checking no. of rows and columns
df.shape
# Out:
# (11251, 13)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western       Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern             Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central       Automobile             Auto       3  23924.0
# 3       Karnataka  Southern     Construction             Auto       2  23912.0
# 4         Gujarat   Western  Food Processing             Auto       2  23877.0

# %%
#Checking for null values
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
# Dropping the 12 rows where the amount is null
df.dropna(inplace=True)

# %%
#Checking no. of rows and columns
df.shape
# Out:
# (11239, 13)

# %%
#Amount column is in float changing it to integer
df['Amount']=df['Amount'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11239 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11239 non-null  int64
#  1   Cust_name         11239 non-null  object
#  2   Product_ID        11239 non-null  object
#  3   Gender            11239 non-null  object
#  4   Age Group         11239 non-null  object
#  5   Age               11239 non-null  int64
#  6   Marital_Status    11239 non-null  int64
#  7   State             11239 non-null  object
#  8   Zone              11239 non-null  object
#  9   Occupation        11239 non-null  object
#  10  Product_Category  11239 non-null  object
#  11  Orders            11239 non-null  int64
#  12  Amount            11239 non-null  int32
# dtypes: int32(1), int64(4), object(8)
# memory usage: 1.2+ MB

# %%
#Checking the datatype of any particular column
df['Occupation'].dtypes
# Out:
# dtype('O')

# %%
#getting the names of thr columns
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
#getting the names of the rows
df.rows
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19780\1283334608.py in ?()
# ----> 2 #getting the names of the rows
#       3 df.rows
#
# c:\users\jyothi\anaconda3\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
#Renaming the Cust_name column to name
df.rename(columns={'Cust_name':'Name'})
# Out:
#        User_ID         Name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
#Getting the description of the data which has mathematical meaning
df[['Age','Orders','Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# # Exploratory Data Analysis

# %%
#Plotting piechart for no of men and women
ax=sns.countplot(x='Gender',data=df)

for bar in ax.containers:
    ax.bar_label(bars)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 5
#       2 ax=sns.countplot(x='Gender',data=df)
#       4 for bar in ax.containers:
# ----> 5     ax.bar_label(bars)
#
# AttributeError: 'AxesSubplot' object has no attribute 'bar_label'

# %%
pip show matplotlib
# Out:
# Name: matplotlib
# Version: 3.3.4
# Summary: Python plotting package
# Home-page: https://matplotlib.org
# Author: John D. Hunter, Michael Droettboom
# Author-email: matplotlib-users@python.org
# License: PSF
# Location: c:\users\jyothi\anaconda3\lib\site-packages
# Requires: pillow, pyparsing, kiwisolver, numpy, cycler, python-dateutil
# Required-by: ydata-profiling, wordcloud, seaborn, scikit-image, phik, autoviz
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install matplotlib=3.8.4
# Out:
# ...
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# ...
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working...
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
#
# Note: you may need to restart the kernel to use updated packages.
# ...
# Examining matplotlib=3.8.4: 100%|##########| 4/4 [00:00<00:00,  4.20it/s]
#
#
# ...
# Examining conflict for python matplotlib:   0%|          | 0/4 [00:00<?, ?it/s]
#
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - matplotlib=3.8.4 -> python[version='>=3.10,<3.11.0a0|>=3.12,<3.13.0a0|>=3.9,<3.10.0a0|>=3.11,<3.12.0a0']
#
# ...

# %%
ax = sns.countplot(x = 'Gender',data = df)

for bars in ax.containers:
    ax.bar_label(bars)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 4
#       1 ax = sns.countplot(x = 'Gender',data = df)
#       3 for bars in ax.containers:
# ----> 4     ax.bar_label(bars)
#
# AttributeError: 'AxesSubplot' object has no attribute 'bar_label'

# %%
# plotting a bar chart for gender vs total amount
sg=df.groupby(['Gender'], as_index=False) ['Amount'].sum().sort_values(by='Amount', ascending =False)

sns.barplot(x='Gender',y='Amount', data=sg)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Amount'>

# %%
#Age distribution frequency
ad= sns.countplot(data=df, x='Age Group', hue='Gender')

# %%
#Age vs amount
aa=df.groupby(['Age Group'], as_index=False) ['Amount'].sum().sort_values(by='Amount', ascending =False)

sns.barplot(x='Age Group',y='Amount', data=aa)
# Out:
# <AxesSubplot:xlabel='Age Group', ylabel='Amount'>

# %%
#Total orders from top 10 states
st=df.groupby(['State'], as_index=False) ['Orders'].sum().sort_values(by='Orders', ascending =False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(x='State', y='Orders', data=st)
# Out:
# <AxesSubplot:xlabel='State', ylabel='Orders'>

# %%
#Total sales from top 10 states
st=df.groupby(['State'], as_index=False) ['Amount'].sum().sort_values(by='Amount', ascending =False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(x='State', y='Amount', data=st)
# Out:
# <AxesSubplot:xlabel='State', ylabel='Amount'>

# %%
#Marital status, gender and their count

ms=sns.countplot(x='Marital_Status', data=df, hue='Gender')

sns.set(rc={'figure.figsize':(7,5)})
for bars in ms.containers:
    ms.bar_label(bars)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 5
#       3 sns.set(rc={'figure.figsize':(7,5)})
#       4 for bars in ms.containers:
# ----> 5     ms.bar_label(bars)
#
# AttributeError: 'AxesSubplot' object has no attribute 'bar_label'

# %%
# Marital status,Gender vs amount
mga=df.groupby(['Marital_Status','Gender'], as_index=False) ['Amount'].sum().sort_values(by='Amount', ascending =False)

sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(x='Marital_Status', y='Amount', data=mga, hue='Gender')
# Out:
# <AxesSubplot:xlabel='Marital_Status', ylabel='Amount'>

# %%
#Occupation
sns.set(rc={'figure.figsize':(20,5)})
sns.countplot(data=df, x='Occupation')
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='count'>

# %%
# Occupation vs amount
ss=df.groupby(['Occupation'], as_index = False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(20,5)})

sns.barplot(data=ss, x='Occupation',y='Amount')
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='Amount'>

# %%
# Product category vs count
sns.set(rc={'figure.figsize':(20,5)})

p=sns.countplot(data=df, x='Product_Category')

for bars in p.containers:
    p.bar_label(bars)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 7
#       4 p=sns.countplot(data=df, x='Product_Category')
#       6 for bars in p.containers:
# ----> 7     p.bar_label(bars)
#
# AttributeError: 'AxesSubplot' object has no attribute 'bar_label'

# %%
# Product category vs amount
ss=df.groupby(['Product_Category'], as_index = False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})

sns.barplot(data=ss, x='Product_Category',y='Amount')
# Out:
# <AxesSubplot:xlabel='Product_Category', ylabel='Amount'>

# %%
# Top 10 states vs amount
ss=df.groupby(['State'], as_index = False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})

sns.barplot(data=ss, x='State',y='Amount')
# Out:
# <AxesSubplot:xlabel='State', ylabel='Amount'>

# %%
# Marital Status
sns.countplot(x='Marital_Status', data=df)
# Out:
# <AxesSubplot:xlabel='Marital_Status', ylabel='count'>

# %%
# Marital Status
sns.countplot(x='Marital_Status', data=df, hue='Gender')
# Out:
# <AxesSubplot:xlabel='Marital_Status', ylabel='count'>

# %%
# Top 10 most sold products
# Top 10 states vs amount
ss=df.groupby(['Product_ID'], as_index = False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})

sns.barplot(data=ss, x='Product_ID',y='Orders')
# Out:
# <AxesSubplot:xlabel='Product_ID', ylabel='Orders'>

# %% [markdown]
# # Conclusion
# ## Maximum sales are done by married women in the age group 26-35 from UP, Mah and Kar working in in IT,Healthcare, Aviation and Banking purchase more  in categories like food, Clothing and electronic gadgets.

# %% [markdown]
# # Thank you!!!
